# %%
import pandas as pd

chunk_size = 1000  # Adjust the chunk size based on your system's capacity
df1 = pd.read_csv(r"C:\Users\varda\Downloads\complaints.csv\complaints.csv")
# Out:
# C:\Users\varda\AppData\Local\Temp\ipykernel_6680\2833498152.py:4: DtypeWarning: Columns (5,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r"C:\Users\varda\Downloads\complaints.csv\complaints.csv")

# %%
df1.shape
# Out:
# (4528267, 18)

# %%
df1.isna().sum()
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235291
# Issue                                 0
# Sub-issue                        724952
# Consumer complaint narrative    2887355
# Company public response         2384053
# Company                               0
# State                             43962
# ZIP code                          30223
# Tags                            4076120
# Consumer consent provided?       918032
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer         10
# Timely response?                      0
# Consumer disputed?              3759912
# Complaint ID                          0
# dtype: int64

# %%
cleaned_df = df1.dropna()

# %%
cleaned_df.shape
# Out:
# (3120, 18)

# %%
df1.head(10)
# Out:
#   Date received                                            Product  \
# 0    2024-01-09  Credit reporting or other personal consumer re...
# 1    2023-12-20  Credit reporting or other personal consumer re...
# 2    2023-12-29  Credit reporting or other personal consumer re...
# 3    2023-12-28                                    Debt collection
# 4    2024-01-01  Credit reporting or other personal consumer re...
# 5    2023-12-29  Credit reporting or other personal consumer re...
# 6    2023-10-10  Credit reporting or other personal consumer re...
# 7    2023-11-12  Credit reporting or other personal consumer re...
# 8    2023-12-22  Credit reporting or other personal consumer re...
# 9    2024-01-08  Credit reporting or other personal consumer re...
#
#                  Sub-product  \
# 0           Credit reporting
# 1           Credit reporting
# 2           Credit reporting
# 3  Federal student loan debt
# 4           Credit reporting
# 5           Credit reporting
# ...

# %%
# cleaned_df_1 = df1.dropna(subset=['Consumer complaint narrative'])

# %%
cleaned_df.isna().sum()
# Out:
# Date received                   0
# Product                         0
# Sub-product                     0
# Issue                           0
# Sub-issue                       0
# Consumer complaint narrative    0
# Company public response         0
# Company                         0
# State                           0
# ZIP code                        0
# Tags                            0
# Consumer consent provided?      0
# Submitted via                   0
# Date sent to company            0
# Company response to consumer    0
# Timely response?                0
# Consumer disputed?              0
# Complaint ID                    0
# dtype: int64

# %%
cleaned_df_1 = cleaned_df.dropna(subset=['Consumer complaint narrative'])

# %%
output_file_path = r'C:\Users\varda\OneDrive\Desktop\nlp_proj\dataset\Final_narrative.csv'
cleaned_df.to_csv(output_file_path, index=False)

# %%
issue_counts = cleaned_df['Issue'].value_counts()

# %%
issues_df = pd.DataFrame({'Issue': issue_counts.index, 'Occurrences': issue_counts.values})

# Save the new DataFrame to a CSV file
# output_file_path = 'C:\Users\varda\OneDrive\Desktop\nlp_proj\dataset\Final_narrative.csv'
issues_df.to_csv(output_file_path, index=False)

print(f"DataFrame saved to: {output_file_path}")

# %%
import pandas as pd

# Assuming 'Issue' is a column in your DataFrame
selected_issues = [
    "Incorrect information on your report",
    "Problem with a credit reporting company's investigation into an existing problem",
    "Improper use of your report",
    "Attempts to collect debt not owed",
    "Managing an account",
    "Trouble during payment process",
    "Written notification about debt",
    "Problem with a purchase shown on your statement",
    "Problem with a company's investigation into an existing problem",
    "Communication tactics",
]

# Filter the DataFrame based on selected issues
final_df_sid = cleaned_df[cleaned_df['Issue'].isin(selected_issues)]

# Save the final DataFrame as a CSV file in the specified directory
final_df_sid.to_csv(r'C:\complaints\final_dataset_sid.csv', index=False)

# Display the first few rows of the final DataFrame
print(final_df_sid.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#       4 selected_issues = [
#       5     "Incorrect information on your report",
#       6     "Problem with a credit reporting company's investigation into an existing problem",
#    (...)
#      14     "Communication tactics",
#      15 ]
#      17 # Filter the DataFrame based on selected issues
# ---> 18 final_df_sid = cleaned_df[cleaned_df['Issue'].isin(selected_issues)]
#      20 # Save the final DataFrame as a CSV file in the specified directory
#      21 final_df_sid.to_csv(r'C:\complaints\final_dataset_sid.csv', index=False)
#
# NameError: name 'cleaned_df' is not defined

# %%
final_df_sid.shape

# %%
# !pip uninstall openai

# %%
pip install openai==0.28

# %%
import openai
import pandas as pd

openai.api_key = "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"

def get_embedding(text, model="text-embedding-ada-002"):
    text = text.replace("\n", " ")
    response = openai.Completion.create(
        engine=model,
        prompt=text,
        max_tokens=0
    )
    return response['choices'][0]['text'].strip()

# Assuming you have a DataFrame named 'result_df'
result_df['ada_embedding'] = result_df['Consumer complaint narrative'].apply(lambda x: get_embedding(x))

# Save the DataFrame to a new CSV file
result_df.to_csv('C:/complaints/final_dataset_v1_with_embeddings.csv', index=False)  # Update the path accordingly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      13     return response['choices'][0]['text'].strip()
#      15 # Assuming you have a DataFrame named 'result_df'
# ---> 16 result_df['ada_embedding'] = result_df['Consumer complaint narrative'].apply(lambda x: get_embedding(x))
#      18 # Save the DataFrame to a new CSV file
#      19 result_df.to_csv('C:/complaints/final_dataset_v1_with_embeddings.csv', index=False)
#
# NameError: name 'result_df' is not defined

# %%
import os

# Replace 'your_api_key_here' with your actual OpenAI API key
api_key = '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'

# Set the OpenAI API key as an environment variable
os.environ['OPENAI_API_KEY'] = api_key

# %%
import pandas as pd
import random

# Your data with Issue and Occurrences columns
given_issues = [
    "Incorrect information on your report",
    "Problem with a credit reporting company's investigation into an existing problem",
    "Incorrect information on credit report",
    "Attempts to collect debt not owed",
    "Trouble during the payment process",
    "Cont'd attempts to collect debt not owed",
    "Struggling to pay mortgage",
    "Managing an account",
    "Dealing with your lender or servicer",
    "Struggling to repay your loan",
    "Loan servicing, payments, escrow account",
    "Managing the loan or lease",
    "Fees or interest",
    "Problem when making payments",
    "Taking/threatening an illegal action",
    "Settling process and costs",
    "Can't repay my loan",
    "Billing disputes",
    "Late fee",
    "Delinquent account",
    "Payoff process",
    "Fraud or scam",
    "Identity theft / Fraud / Embezzlement",
    "Unauthorized transactions or other transaction problems",
    "Unauthorized transactions/trans. issues",
    "Lost or stolen check",
    "Lost or stolen money order",
    "Can't stop withdrawals from your bank account",
    "Can't stop charges to bank account",
    "Opening an account",
    "Closing an account",
    "Closing your account",
    "Managing, opening, or closing your mobile wallet account",
    "Dealing with my lender or servicer",
    "Problem with a company's investigation into an existing issue",
    "Problem with the payoff process at the end of the loan",
    "Can't contact lender or servicer",
    "Can't contact lender",
    "Managing, opening, or closing account",
    "Can't stop withdrawals from your bank account",
    "Getting a credit card",
    "Trouble using your card",
    "Charged fees or interest you didn't expect"
]



# Set the desired number of occurrences to select for each category
rows_per_issue = 80

# Create an empty DataFrame to store the filtered results
result_df = pd.DataFrame()

# Iterate over each given issue
for issue in given_issues:
    # Filter the DataFrame for the current issue
    issue_df = cleaned_df[cleaned_df['Issue'] == issue]
    
    # Check if there are at least 50 unique rows for the current issue
    if len(issue_df) >= rows_per_issue:
        # Select 50 unique rows randomly
        selected_rows = issue_df.sample(n=rows_per_issue, random_state=42)  # You can change the random_state as needed
        
        # Concatenate the selected rows to the result DataFrame
        result_df = pd.concat([result_df, selected_rows], ignore_index=True)
    else:
        # If there are not enough rows, include all rows for the current issue
        result_df = pd.concat([result_df, issue_df], ignore_index=True)

# Save the result DataFrame to a new CSV file
result_df.to_csv('C:\\complaints\\new\\filtered_new_issues_80_per_issue.csv', index=False)

# Display a message indicating the process is complete
print("Filtered DataFrame saved successfully.")
